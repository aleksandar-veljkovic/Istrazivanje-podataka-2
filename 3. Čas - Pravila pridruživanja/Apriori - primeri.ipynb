# %%
from apyori import apriori
import pandas as pd

# %%
data = pd.read_csv('Grocery Products Purchase.csv')

# %%
data
# Out:
#                 Product 1            Product 2         Product 3  \
# 0            citrus fruit  semi-finished bread         margarine
# 1          tropical fruit               yogurt            coffee
# 2              whole milk                  NaN               NaN
# 3               pip fruit               yogurt      cream cheese
# 4        other vegetables           whole milk    condensed milk
# ...                   ...                  ...               ...
# 9830              sausage              chicken              beef
# 9831    cooking chocolate                  NaN               NaN
# 9832              chicken         citrus fruit  other vegetables
# 9833  semi-finished bread        bottled water              soda
# 9834              chicken       tropical fruit  other vegetables
#
#                      Product 4      Product 5       Product 6  \
# 0                  ready soups            NaN             NaN
# ...

# %%
transactions = []
for index, row in data.iterrows():
    items = [x for x in row.values if isinstance(x, str)]
    transactions.append(items)

# %%
transactions
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
# ...

# %%
res = apriori(transactions, min_support=0.001, min_confidence=0.7, min_lift=4)
for record in res:
#     print(record)
    if len(record.items) > 1:
        base = list(record.ordered_statistics[0].items_base)
        items = list(record.ordered_statistics[0].items_add)
        support = round(record.support * 100, 2)
        confidence = round(record.ordered_statistics[0].confidence * 100, 2)
        lift = round(record.ordered_statistics[0].lift, 2)
        
        print(f'{", ".join(base)} => {", ".join(items)}[S={support}%, C={confidence}%, L={lift}]')
# Out:
# liquor, red/blush wine => bottled beer[S=0.19%, C=90.48%, L=11.24]
# onions, butter milk => other vegetables[S=0.13%, C=81.25%, L=4.2]
# butter milk, pork => other vegetables[S=0.18%, C=85.71%, L=4.43]
# misc. beverages, coffee => soda[S=0.1%, C=76.92%, L=4.41]
# turkey, curd => other vegetables[S=0.12%, C=80.0%, L=4.13]
# frozen vegetables, rice => other vegetables[S=0.11%, C=78.57%, L=4.06]
# fruit/vegetable juice, herbs => other vegetables[S=0.12%, C=80.0%, L=4.13]
# grapes, onions => other vegetables[S=0.11%, C=91.67%, L=4.74]
# oil, hard cheese => other vegetables[S=0.11%, C=91.67%, L=4.74]
# shopping bags, herbs => other vegetables[S=0.19%, C=82.61%, L=4.27]
# meat, margarine => other vegetables[S=0.17%, C=85.0%, L=4.39]
# spread cheese, newspapers => rolls/buns[S=0.12%, C=75.0%, L=4.08]
# onions, sliced cheese => other vegetables[S=0.15%, C=78.95%, L=4.08]
# onions, waffles => other vegetables[S=0.12%, C=80.0%, L=4.13]
# ...

# %%
data = pd.read_csv('dataset.csv')

# %%
X = data.iloc[:,1:]
X
# Out:
#                  Symptom_1              Symptom_2              Symptom_3  \
# 0                  itching              skin_rash   nodal_skin_eruptions
# 1                skin_rash   nodal_skin_eruptions    dischromic _patches
# 2                  itching   nodal_skin_eruptions    dischromic _patches
# 3                  itching              skin_rash    dischromic _patches
# 4                  itching              skin_rash   nodal_skin_eruptions
# ...                    ...                    ...                    ...
# 4915              vomiting               headache                 nausea
# 4916             skin_rash     pus_filled_pimples             blackheads
# 4917   burning_micturition     bladder_discomfort    foul_smell_of urine
# 4918             skin_rash             joint_pain           skin_peeling
# 4919             skin_rash             high_fever                blister
#
#                       Symptom_4              Symptom_5            Symptom_6  \
# ...

# %%
transactions = []
for index, row in X.iterrows():
    items = [x for x in row.values if isinstance(x, str)]
    transactions.append(items)

# %%
res = apriori(transactions, min_support=0.05, min_confidence=0.6, min_lift=4)
for record in res:
#     print(record)
    if len(record.items) > 1:
        base = list(record.ordered_statistics[0].items_base)
        items = list(record.ordered_statistics[0].items_add)
        support = round(record.support * 100, 2)
        confidence = round(record.ordered_statistics[0].confidence * 100, 2)
        lift = round(record.ordered_statistics[0].lift, 2)
        
        print(f'{", ".join(base)} => {", ".join(items)}[S={support}%, C={confidence}%, L={lift}]')
# Out:
#  dark_urine =>  abdominal_pain[S=11.1%, C=95.79%, L=4.57]
#  blurred_and_distorted_vision =>  excessive_hunger[S=6.71%, C=96.49%, L=10.28]
#  breathlessness =>  chest_pain[S=6.71%, C=73.33%, L=5.18]
#  breathlessness =>  cough[S=6.46%, C=70.67%, L=6.16]
#  breathlessness =>  sweating[S=6.34%, C=69.33%, L=5.03]
#  chest_pain =>  cough[S=9.15%, C=64.66%, L=5.64]
#  phlegm =>  chest_pain[S=7.2%, C=100.0%, L=7.07]
#  muscle_pain =>  chills[S=6.83%, C=70.89%, L=4.37]
#  phlegm =>  chills[S=6.83%, C=94.92%, L=5.85]
#  phlegm =>  cough[S=6.83%, C=94.92%, L=8.28]
#  dark_urine =>  yellowing_of_eyes[S=9.15%, C=78.95%, L=4.76]
#  dark_urine =>  yellowish_skin[S=10.98%, C=94.74%, L=5.11]
#  excessive_hunger =>  irritability[S=6.95%, C=74.03%, L=7.68]
#  mild_fever =>  loss_of_appetite[S=6.95%, C=96.61%, L=4.13]
#  loss_of_appetite =>  yellowing_of_eyes[S=15.98%, C=68.23%, L=4.11]
#  phlegm =>  malaise[S=6.95%, C=96.61%, L=6.77]
#  swelled_lymph_nodes =>  malaise[S=6.95%, C=98.28%, L=6.89]
# ...

# %%
f = open('disease and symptoms.json')
from json import loads
transactions = loads(f.read())

# %%
transactions
# Out:
# [['Anxiety and nervousness',
#   'Depression',
#   'Shortness of breath',
#   'Depressive or psychotic symptoms',
#   'Sharp chest pain',
#   'Dizziness',
#   'Insomnia',
#   'Abnormal involuntary movements',
#   'Chest tightness',
#   'Palpitations',
#   'Irregular heartbeat',
#   'Breathing fast'],
#  ['Hoarse voice',
#   'Sore throat',
#   'Difficulty speaking',
#   'Cough',
#   'Nasal congestion',
#   'Throat swelling',
#   'Diminished hearing',
#   'Lump in throat',
#   'Throat feels tight',
#   'Difficulty in swallowing',
#   'Skin swelling',
#   'Retention of urine'],
#  ['Groin mass',
#   'Leg pain',
#   'Hip pain',
#   'Suprapubic pain',
#   'Blood in stool',
#   'Lack of growth',
#   'Diminished hearing',
#   'Depression',
#   'Emotional symptoms',
#   'Elbow weakness',
#   'Back weakness',
#   'Pus in sputum'],
#  ['Symptoms of the scrotum and testes',
#   'Swelling of scrotum',
#   'Pain in testicles',
#   'Flatulence',
#   'Pus draining from ear',
#   'Jaundice',
# ...

# %%
res = apriori(transactions, min_support=0.05, min_confidence=0.4, min_lift=2)
for record in res:
#     print(record)
    if len(record.items) > 1:
        base = list(record.ordered_statistics[0].items_base)
        items = list(record.ordered_statistics[0].items_add)
        support = round(record.support * 100, 2)
        confidence = round(record.ordered_statistics[0].confidence * 100, 2)
        lift = round(record.ordered_statistics[0].lift, 2)
        
        print(f'{", ".join(base)} => {", ".join(items)}[S={support}%, C={confidence}%, L={lift}]')
# Out:
# Abnormal appearing skin => Itching of skin[S=5.15%, C=48.81%, L=6.17]
# Abnormal appearing skin => Skin lesion[S=5.78%, C=54.76%, L=5.81]
# Abnormal appearing skin => Skin rash[S=5.15%, C=48.81%, L=5.4]
# Abnormal appearing skin => Skin swelling[S=5.4%, C=51.19%, L=6.47]
# Leg pain => Back pain[S=5.03%, C=47.62%, L=3.51]
# Burning abdominal pain => Sharp abdominal pain[S=6.03%, C=92.31%, L=4.54]
# Cough => Fever[S=7.79%, C=55.36%, L=3.93]
# Cough => Nasal congestion[S=6.78%, C=48.21%, L=6.0]
# Sore throat => Cough[S=5.28%, C=76.36%, L=5.43]
# Diarrhea => Nausea[S=5.28%, C=75.0%, L=5.38]
# Diarrhea => Sharp abdominal pain[S=5.9%, C=83.93%, L=4.12]
# Diarrhea => Vomiting[S=5.15%, C=73.21%, L=4.52]
# Diminished vision => Pain in eye[S=5.53%, C=68.75%, L=7.11]
# Dizziness => Headache[S=6.28%, C=46.73%, L=2.45]
# Dizziness => Weakness[S=5.53%, C=41.12%, L=3.68]
# Nasal congestion => Fever[S=5.4%, C=67.19%, L=4.78]
# Sore throat => Fever[S=5.15%, C=74.55%, L=5.3]
# ...
